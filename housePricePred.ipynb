# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.pandas.set_option('display.max_columns',None)

# %%
dataset = pd.read_csv('train.csv')

# %%
dataset.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### In Data Analysis We Will Analyze To Find Out The Below Stuff
# - Missing Values
# - All the Numerical Variables
# - Distribution of the Numerical Variables
# - Categorical Varibles
# - Cardioality of Categorical Varibles
# - Outliers
# - Reletionship between independent and dependent feature(Sales Price)

# %%
featureWithNull = [feature for feature in dataset.columns if dataset[feature].isnull().sum()>=1]

# %%
len(featureWithNull)
# Out:
# 19

# %%
for f in featureWithNull:
    print(f"{f}: {np.round(dataset[f].isnull().mean(),3)}% Missing")
# Out:
# LotFrontage: 0.177% Missing
# Alley: 0.938% Missing
# MasVnrType: 0.005% Missing
# MasVnrArea: 0.005% Missing
# BsmtQual: 0.025% Missing
# BsmtCond: 0.025% Missing
# BsmtExposure: 0.026% Missing
# BsmtFinType1: 0.025% Missing
# BsmtFinType2: 0.026% Missing
# Electrical: 0.001% Missing
# FireplaceQu: 0.473% Missing
# GarageType: 0.055% Missing
# GarageYrBlt: 0.055% Missing
# GarageFinish: 0.055% Missing
# GarageQual: 0.055% Missing
# GarageCond: 0.055% Missing
# PoolQC: 0.995% Missing
# Fence: 0.808% Missing
# MiscFeature: 0.963% Missing

# %% [markdown]
# ## Since there have some missing values, we should find out the reletion between missing values and sales price
# lets plot some diagram to see this

# %%
data = dataset.copy()
for f in featureWithNull:
    data[f] = np.where(data[f].isnull(),0,1)
    data.groupby(f)['SalePrice'].median().plot.bar()
    plt.title(f)
    plt.show()

# %% [markdown]
# We show that there have a high reletion between null values and sales price

# %%
len(dataset.Id)
# Out:
# 1460

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
numericFeature = [feature for feature in dataset.columns if dataset[feature].dtype != 'O']
len(numericFeature)
# Out:
# 38

# %%
dataset[numericFeature].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0       856       854             0       1710             1             0
# 1      1262         0             0       1262             0             1
# 2       920       866             0       1786             1             0
# 3       961       756             0       1717             1             0
# 4      1145      1053             0       2198             1             0
#
#    FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 0         2         1             3             1             8           0
# 1         2         0             3             1             6           1
# 2         2         1             3             1             6           1
# 3         1         0             3             1             7           1
# 4         2         1             4             1             9           1
#
#    GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 0       2003.0           2         548           0           61
# 1       1976.0           2         460         298            0
# 2       2001.0           2         608           0           42
# 3       1998.0           3         642           0           35
# 4       2000.0           3         836         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %%
yearFeature = [year for year in numericFeature if 'Yr' in year or 'Year' in year]
yearFeature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for year in yearFeature:
    print(year, dataset[year].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# GarageYrBlt [2003. 1976. 2001. 1998. 2000. 1993. 2004. 1973. 1931. 1939. 1965. 2005.
#  1962. 2006. 1960. 1991. 1970. 1967. 1958. 1930. 2002. 1968. 2007. 2008.
#  1957. 1920. 1966. 1959. 1995. 1954. 1953.   nan 1983. 1977. 1997. 1985.
#  1963. 1981. 1964. 1999. 1935. 1990. 1945. 1987. 1989. 1915. 1956. 1948.
#  1974. 2009. 1950. 1961. 1921. 1900. 1979. 1951. 1969. 1936. 1975. 1971.
#  1923. 1984. 1926. 1955. 1986. 1988. 1916. 1932. 1972. 1918. 1980. 1924.
#  1996. 1940. 1949. 1994. 1910. 1978. 1982. 1992. 1925. 1941. 2010. 1927.
#  1947. 1937. 1942. 1938. 1952. 1928. 1922. 1934. 1906. 1914. 1946. 1908.
#  1929. 1933.]
# YrSold [2008 2007 2006 2009 2010]

# %%
yearFeature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
dataset.columns[-1]
# Out:
# 'SalePrice'

# %%
dataset.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median House Price')
plt.title("Year Sold vs Median House Price")
plt.show()

# %%
data = dataset.copy()
for year in yearFeature:
    if year != 'YrSold':
        data[year] = data['YrSold'] - data[year]
        plt.scatter(data[year],data['SalePrice'])
        plt.xlabel(year)
        plt.ylabel('Sale Price')
        plt.show()

# %%
descreateFeature = [descreat for descreat in numericFeature if len(dataset[descreat].unique())<25 and descreat not in yearFeature+['Id'] ]
descreateFeature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
len(descreateFeature)
# Out:
# 17

# %%
dataset[descreateFeature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# 0           0           2          0         0        0       2
# 1           1           2          0         0        0       5
# 2           1           2          0         0        0       9
# 3           1           3          0         0        0       2
# 4           1           3          0         0        0      12

# %%
data = dataset.copy()
for f in descreateFeature:
    data.groupby(f)['SalePrice'].median().plot.bar()
    plt.xlabel(f)
    plt.ylabel('Sale Price')
    plt.title(f)
    plt.show()

# %%
continuesFeature = [ con for con in numericFeature if con not in descreateFeature+yearFeature+['Id'] ]
len(continuesFeature)
# Out:
# 16

# %%
data = dataset.copy()
for f in continuesFeature:
    data[f].hist(bins=25)
    plt.xlabel(f)
    plt.ylabel('Count')
    plt.title(f)
    plt.show()

# %%
data = dataset.copy()
data['SalePrice'] = np.log(data['SalePrice'])
for con in continuesFeature:
    if 0 not in data[con].unique():
        data[con] = np.log(data[con])
        plt.scatter(data[con],data['SalePrice'])
        plt.xlabel(con)
        plt.ylabel('Sales Price')
        plt.title(con)
        plt.show()

# %% [markdown]
# # Outlier

# %%
data = dataset.copy()
data['SalePrice'] = np.log(data['SalePrice'])
for con in continuesFeature:
    if 0 not in data[con].unique():
        data[con] = np.log(data[con])
        data.boxplot(column = con)
        plt.ylabel(con)
        plt.title(con)
        plt.show()

# %% [markdown]
# # Categorical Feature

# %%
catFeature = [feature for feature in dataset.columns if dataset[feature].dtype == 'O']
len(catFeature)
# Out:
# 43

# %%
dataset[catFeature].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
#   Exterior1st Exterior2nd MasVnrType ExterQual ExterCond Foundation BsmtQual  \
# 0     VinylSd     VinylSd    BrkFace        Gd        TA      PConc       Gd
# 1     MetalSd     MetalSd       None        TA        TA     CBlock       Gd
# 2     VinylSd     VinylSd    BrkFace        Gd        TA      PConc       Gd
# 3     Wd Sdng     Wd Shng       None        TA        TA     BrkTil       TA
# 4     VinylSd     VinylSd    BrkFace        Gd        TA      PConc       Gd
#
#   BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 Heating HeatingQC  \
# 0       TA           No          GLQ          Unf    GasA        Ex
# 1       TA           Gd          ALQ          Unf    GasA        Ex
# 2       TA           Mn          GLQ          Unf    GasA        Ex
# 3       Gd           No          ALQ          Unf    GasA        Gd
# 4       TA           Av          GLQ          Unf    GasA        Ex
#
#   CentralAir Electrical KitchenQual Functional FireplaceQu GarageType  \
# 0          Y      SBrkr          Gd        Typ         NaN     Attchd
# 1          Y      SBrkr          TA        Typ          TA     Attchd
# 2          Y      SBrkr          Gd        Typ          TA     Attchd
# 3          Y      SBrkr          Gd        Typ          Gd     Detchd
# 4          Y      SBrkr          Gd        Typ          TA     Attchd
#
#   GarageFinish GarageQual GarageCond PavedDrive PoolQC Fence MiscFeature  \
# 0          RFn         TA         TA          Y    NaN   NaN         NaN
# 1          RFn         TA         TA          Y    NaN   NaN         NaN
# 2          RFn         TA         TA          Y    NaN   NaN         NaN
# 3          Unf         TA         TA          Y    NaN   NaN         NaN
# 4          RFn         TA         TA          Y    NaN   NaN         NaN
#
#   SaleType SaleCondition
# 0       WD        Normal
# 1       WD        Normal
# 2       WD        Normal
# 3       WD       Abnorml
# 4       WD        Normal

# %%
for f in catFeature:
    print(f"The feature is {f} and the number of catagories are {len(dataset[f].unique())}")
# Out:
# The feature is MSZoning and the number of catagories are 5
# The feature is Street and the number of catagories are 2
# The feature is Alley and the number of catagories are 3
# The feature is LotShape and the number of catagories are 4
# The feature is LandContour and the number of catagories are 4
# The feature is Utilities and the number of catagories are 2
# The feature is LotConfig and the number of catagories are 5
# The feature is LandSlope and the number of catagories are 3
# The feature is Neighborhood and the number of catagories are 25
# The feature is Condition1 and the number of catagories are 9
# The feature is Condition2 and the number of catagories are 8
# The feature is BldgType and the number of catagories are 5
# The feature is HouseStyle and the number of catagories are 8
# The feature is RoofStyle and the number of catagories are 6
# The feature is RoofMatl and the number of catagories are 8
# The feature is Exterior1st and the number of catagories are 15
# The feature is Exterior2nd and the number of catagories are 16
# The feature is MasVnrType and the number of catagories are 5
# The feature is ExterQual and the number of catagories are 4
# The feature is ExterCond and the number of catagories are 5
# The feature is Foundation and the number of catagories are 6
# The feature is BsmtQual and the number of catagories are 5
# The feature is BsmtCond and the number of catagories are 5
# The feature is BsmtExposure and the number of catagories are 5
# The feature is BsmtFinType1 and the number of catagories are 7
# The feature is BsmtFinType2 and the number of catagories are 7
# The feature is Heating and the number of catagories are 6
# The feature is HeatingQC and the number of catagories are 5
# The feature is CentralAir and the number of catagories are 2
# The feature is Electrical and the number of catagories are 6
# The feature is KitchenQual and the number of catagories are 4
# The feature is Functional and the number of catagories are 7
# The feature is FireplaceQu and the number of catagories are 6
# The feature is GarageType and the number of catagories are 7
# The feature is GarageFinish and the number of catagories are 4
# The feature is GarageQual and the number of catagories are 6
# The feature is GarageCond and the number of catagories are 6
# The feature is PavedDrive and the number of catagories are 3
# The feature is PoolQC and the number of catagories are 4
# The feature is Fence and the number of catagories are 5
# The feature is MiscFeature and the number of catagories are 5
# The feature is SaleType and the number of catagories are 9
# The feature is SaleCondition and the number of catagories are 6

# %%
data = dataset.copy()
for f in catFeature:
    data.groupby(f)['SalePrice'].median().plot.bar()
    plt.xlabel(f)
    plt.ylabel('Sale Price')
    plt.title(f)
    plt.show()
